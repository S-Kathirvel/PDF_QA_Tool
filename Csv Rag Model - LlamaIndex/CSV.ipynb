# %%
import pandas as pd

from pathlib import Path


def process_csv_folders(data_dir):
	"""
	Processes all CSV files within subfolders of the given data directory.

	Args:
			data_dir (Path): Path to the directory containing subfolders with CSV files.

	Returns:
			list: A list of pandas DataFrames, one for each CSV file found.
	"""
	dfs = []
	# Loop through subfolders (assuming folder names start with numbers)
	for folder in sorted(f for f in data_dir.iterdir() if f.is_dir()):
		folder_path = data_dir / folder  # Combine data_dir with folder name
		csv_files = sorted(folder_path.glob("*.csv"))
		for csv_file in csv_files:
			print(f"Processing file: {csv_file}")
			try:
				df = pd.read_csv(csv_file)
				dfs.append(df)
			except Exception as e:
				print(f"Error parsing {csv_file}: {str(e)}")
	return dfs


# Set the data directory path (replace with your actual path)
data_dir = Path("F:/Internship/CSV/data")

# Process all CSV files in subfolders
dfs = process_csv_folders(data_dir)

# Now you have a list 'all_dfs' containing DataFrames from all CSV files
print("Successfully processed all CSV files!")
# Out:
# Processing file: F:\Internship\CSV\data\200-csv\0.csv
# Processing file: F:\Internship\CSV\data\200-csv\1.csv
# Processing file: F:\Internship\CSV\data\200-csv\10.csv
# Processing file: F:\Internship\CSV\data\200-csv\11.csv
# Processing file: F:\Internship\CSV\data\200-csv\12.csv
# Processing file: F:\Internship\CSV\data\200-csv\14.csv
# Processing file: F:\Internship\CSV\data\200-csv\15.csv
# Error parsing F:\Internship\CSV\data\200-csv\15.csv: Error tokenizing data. C error: Expected 4 fields in line 16, saw 5
#
# Processing file: F:\Internship\CSV\data\200-csv\17.csv
# Error parsing F:\Internship\CSV\data\200-csv\17.csv: Error tokenizing data. C error: Expected 6 fields in line 5, saw 7
#
# Processing file: F:\Internship\CSV\data\200-csv\18.csv
# Processing file: F:\Internship\CSV\data\200-csv\20.csv
# Processing file: F:\Internship\CSV\data\200-csv\22.csv
# Processing file: F:\Internship\CSV\data\200-csv\24.csv
# Processing file: F:\Internship\CSV\data\200-csv\25.csv
# Processing file: F:\Internship\CSV\data\200-csv\26.csv
# Processing file: F:\Internship\CSV\data\200-csv\28.csv
# Processing file: F:\Internship\CSV\data\200-csv\29.csv
# Processing file: F:\Internship\CSV\data\200-csv\3.csv
# Processing file: F:\Internship\CSV\data\200-csv\30.csv
# Processing file: F:\Internship\CSV\data\200-csv\31.csv
# Processing file: F:\Internship\CSV\data\200-csv\32.csv
# Processing file: F:\Internship\CSV\data\200-csv\33.csv
# Processing file: F:\Internship\CSV\data\200-csv\34.csv
# Error parsing F:\Internship\CSV\data\200-csv\34.csv: Error tokenizing data. C error: Expected 4 fields in line 6, saw 13
#
# Processing file: F:\Internship\CSV\data\200-csv\35.csv
# Processing file: F:\Internship\CSV\data\200-csv\36.csv
# Processing file: F:\Internship\CSV\data\200-csv\37.csv
# Processing file: F:\Internship\CSV\data\200-csv\38.csv
# Processing file: F:\Internship\CSV\data\200-csv\4.csv
# Processing file: F:\Internship\CSV\data\200-csv\41.csv
# Processing file: F:\Internship\CSV\data\200-csv\42.csv
# Processing file: F:\Internship\CSV\data\200-csv\44.csv
# Processing file: F:\Internship\CSV\data\204-csv\786.csv
# Processing file: F:\Internship\CSV\data\204-csv\787.csv
# Error parsing F:\Internship\CSV\data\204-csv\787.csv: Error tokenizing data. C error: Expected 5 fields in line 10, saw 7
#
# Processing file: F:\Internship\CSV\data\204-csv\788.csv
# Processing file: F:\Internship\CSV\data\204-csv\789.csv
# Processing file: F:\Internship\CSV\data\204-csv\79.csv
# Processing file: F:\Internship\CSV\data\204-csv\790.csv
# Processing file: F:\Internship\CSV\data\204-csv\791.csv
# Processing file: F:\Internship\CSV\data\204-csv\792.csv
# Processing file: F:\Internship\CSV\data\204-csv\793.csv
# Processing file: F:\Internship\CSV\data\204-csv\794.csv
# Processing file: F:\Internship\CSV\data\204-csv\795.csv
# Processing file: F:\Internship\CSV\data\204-csv\796.csv
# Processing file: F:\Internship\CSV\data\204-csv\797.csv
# Processing file: F:\Internship\CSV\data\204-csv\798.csv
# Processing file: F:\Internship\CSV\data\204-csv\799.csv
# Processing file: F:\Internship\CSV\data\204-csv\8.csv
# Processing file: F:\Internship\CSV\data\204-csv\80.csv
# Processing file: F:\Internship\CSV\data\204-csv\800.csv
# Processing file: F:\Internship\CSV\data\204-csv\801.csv
# Processing file: F:\Internship\CSV\data\204-csv\802.csv
# Processing file: F:\Internship\CSV\data\204-csv\803.csv
# Processing file: F:\Internship\CSV\data\204-csv\804.csv
# Processing file: F:\Internship\CSV\data\204-csv\805.csv
# Processing file: F:\Internship\CSV\data\204-csv\806.csv
# Processing file: F:\Internship\CSV\data\204-csv\807.csv
# Processing file: F:\Internship\CSV\data\204-csv\808.csv
# Processing file: F:\Internship\CSV\data\204-csv\809.csv
# Processing file: F:\Internship\CSV\data\204-csv\81.csv
# Processing file: F:\Internship\CSV\data\204-csv\810.csv
# Processing file: F:\Internship\CSV\data\204-csv\811.csv
# Processing file: F:\Internship\CSV\data\204-csv\812.csv
# Processing file: F:\Internship\CSV\data\204-csv\813.csv
# Processing file: F:\Internship\CSV\data\204-csv\814.csv
# Processing file: F:\Internship\CSV\data\204-csv\815.csv
# Processing file: F:\Internship\CSV\data\204-csv\816.csv
# Processing file: F:\Internship\CSV\data\204-csv\817.csv
# Processing file: F:\Internship\CSV\data\204-csv\818.csv
# Processing file: F:\Internship\CSV\data\204-csv\819.csv
# Processing file: F:\Internship\CSV\data\204-csv\82.csv
# Processing file: F:\Internship\CSV\data\204-csv\820.csv
# Processing file: F:\Internship\CSV\data\204-csv\821.csv
# Processing file: F:\Internship\CSV\data\204-csv\822.csv
# Processing file: F:\Internship\CSV\data\204-csv\823.csv
# Error parsing F:\Internship\CSV\data\204-csv\823.csv: Error tokenizing data. C error: Expected 5 fields in line 8, saw 6
#
# Processing file: F:\Internship\CSV\data\204-csv\824.csv
# Processing file: F:\Internship\CSV\data\204-csv\825.csv
# Processing file: F:\Internship\CSV\data\204-csv\826.csv
# Processing file: F:\Internship\CSV\data\204-csv\827.csv
# Processing file: F:\Internship\CSV\data\204-csv\828.csv
# Processing file: F:\Internship\CSV\data\204-csv\829.csv
# Processing file: F:\Internship\CSV\data\204-csv\83.csv
# Processing file: F:\Internship\CSV\data\204-csv\830.csv
# Processing file: F:\Internship\CSV\data\204-csv\831.csv
# Error parsing F:\Internship\CSV\data\204-csv\831.csv: Error tokenizing data. C error: Expected 6 fields in line 13, saw 7
#
# Processing file: F:\Internship\CSV\data\204-csv\832.csv
# Processing file: F:\Internship\CSV\data\204-csv\833.csv
# Processing file: F:\Internship\CSV\data\204-csv\834.csv
# Processing file: F:\Internship\CSV\data\204-csv\835.csv
# Processing file: F:\Internship\CSV\data\204-csv\836.csv
# Processing file: F:\Internship\CSV\data\204-csv\837.csv
# Processing file: F:\Internship\CSV\data\204-csv\838.csv
# Processing file: F:\Internship\CSV\data\204-csv\839.csv
# Processing file: F:\Internship\CSV\data\204-csv\84.csv
# Processing file: F:\Internship\CSV\data\204-csv\840.csv
# Error parsing F:\Internship\CSV\data\204-csv\840.csv: Error tokenizing data. C error: Expected 7 fields in line 3, saw 8
#
# Processing file: F:\Internship\CSV\data\204-csv\841.csv
# Processing file: F:\Internship\CSV\data\204-csv\842.csv
# Processing file: F:\Internship\CSV\data\204-csv\843.csv
# Processing file: F:\Internship\CSV\data\204-csv\844.csv
# Processing file: F:\Internship\CSV\data\204-csv\845.csv
# Processing file: F:\Internship\CSV\data\204-csv\846.csv
# Processing file: F:\Internship\CSV\data\204-csv\847.csv
# Processing file: F:\Internship\CSV\data\204-csv\848.csv
# Processing file: F:\Internship\CSV\data\204-csv\849.csv
# Processing file: F:\Internship\CSV\data\204-csv\85.csv
# Processing file: F:\Internship\CSV\data\204-csv\850.csv
# Processing file: F:\Internship\CSV\data\204-csv\851.csv
# Error parsing F:\Internship\CSV\data\204-csv\851.csv: Error tokenizing data. C error: Expected 7 fields in line 14, saw 12
#
# Processing file: F:\Internship\CSV\data\204-csv\852.csv
# Processing file: F:\Internship\CSV\data\204-csv\853.csv
# Processing file: F:\Internship\CSV\data\204-csv\854.csv
# Processing file: F:\Internship\CSV\data\204-csv\855.csv
# Processing file: F:\Internship\CSV\data\204-csv\856.csv
# Processing file: F:\Internship\CSV\data\204-csv\857.csv
# Processing file: F:\Internship\CSV\data\204-csv\858.csv
# Processing file: F:\Internship\CSV\data\204-csv\859.csv
# Processing file: F:\Internship\CSV\data\204-csv\86.csv
# Processing file: F:\Internship\CSV\data\204-csv\860.csv
# Processing file: F:\Internship\CSV\data\204-csv\861.csv
# Processing file: F:\Internship\CSV\data\204-csv\862.csv
# Processing file: F:\Internship\CSV\data\204-csv\863.csv
# Processing file: F:\Internship\CSV\data\204-csv\864.csv
# Processing file: F:\Internship\CSV\data\204-csv\865.csv
# Processing file: F:\Internship\CSV\data\204-csv\866.csv
# Processing file: F:\Internship\CSV\data\204-csv\867.csv
# Processing file: F:\Internship\CSV\data\204-csv\868.csv
# Processing file: F:\Internship\CSV\data\204-csv\869.csv
# Processing file: F:\Internship\CSV\data\204-csv\87.csv
# Processing file: F:\Internship\CSV\data\204-csv\870.csv
# Processing file: F:\Internship\CSV\data\204-csv\918.csv
# Processing file: F:\Internship\CSV\data\204-csv\919.csv
# Error parsing F:\Internship\CSV\data\204-csv\919.csv: Error tokenizing data. C error: Expected 5 fields in line 11, saw 6
#
# Processing file: F:\Internship\CSV\data\204-csv\92.csv
# Processing file: F:\Internship\CSV\data\204-csv\920.csv
# Processing file: F:\Internship\CSV\data\204-csv\921.csv
# Processing file: F:\Internship\CSV\data\204-csv\922.csv
# Processing file: F:\Internship\CSV\data\204-csv\923.csv
# Processing file: F:\Internship\CSV\data\204-csv\924.csv
# Processing file: F:\Internship\CSV\data\204-csv\925.csv
# Processing file: F:\Internship\CSV\data\204-csv\926.csv
# Processing file: F:\Internship\CSV\data\204-csv\927.csv
# Processing file: F:\Internship\CSV\data\204-csv\928.csv
# Processing file: F:\Internship\CSV\data\204-csv\929.csv
# Processing file: F:\Internship\CSV\data\204-csv\93.csv
# Processing file: F:\Internship\CSV\data\204-csv\930.csv
# Processing file: F:\Internship\CSV\data\204-csv\931.csv
# Processing file: F:\Internship\CSV\data\204-csv\932.csv
# Processing file: F:\Internship\CSV\data\204-csv\933.csv
# Processing file: F:\Internship\CSV\data\204-csv\934.csv
# Processing file: F:\Internship\CSV\data\204-csv\935.csv
# Processing file: F:\Internship\CSV\data\204-csv\936.csv
# Processing file: F:\Internship\CSV\data\204-csv\937.csv
# Processing file: F:\Internship\CSV\data\204-csv\938.csv
# Processing file: F:\Internship\CSV\data\204-csv\939.csv
# Processing file: F:\Internship\CSV\data\204-csv\94.csv
# Processing file: F:\Internship\CSV\data\204-csv\940.csv
# Processing file: F:\Internship\CSV\data\204-csv\941.csv
# Processing file: F:\Internship\CSV\data\204-csv\942.csv
# Processing file: F:\Internship\CSV\data\204-csv\943.csv
# Processing file: F:\Internship\CSV\data\204-csv\944.csv
# Processing file: F:\Internship\CSV\data\204-csv\945.csv
# Processing file: F:\Internship\CSV\data\204-csv\946.csv
# Processing file: F:\Internship\CSV\data\204-csv\947.csv
# Processing file: F:\Internship\CSV\data\204-csv\948.csv
# Processing file: F:\Internship\CSV\data\204-csv\949.csv
# Processing file: F:\Internship\CSV\data\204-csv\95.csv
# Processing file: F:\Internship\CSV\data\204-csv\950.csv
# Processing file: F:\Internship\CSV\data\204-csv\951.csv
# Processing file: F:\Internship\CSV\data\204-csv\952.csv
# Processing file: F:\Internship\CSV\data\204-csv\953.csv
# Processing file: F:\Internship\CSV\data\204-csv\954.csv
# Processing file: F:\Internship\CSV\data\204-csv\955.csv
# Processing file: F:\Internship\CSV\data\204-csv\956.csv
# Processing file: F:\Internship\CSV\data\204-csv\957.csv
# Processing file: F:\Internship\CSV\data\204-csv\958.csv
# Processing file: F:\Internship\CSV\data\204-csv\959.csv
# Processing file: F:\Internship\CSV\data\204-csv\96.csv
# Processing file: F:\Internship\CSV\data\204-csv\960.csv
# Processing file: F:\Internship\CSV\data\204-csv\961.csv
# Processing file: F:\Internship\CSV\data\204-csv\962.csv
# Processing file: F:\Internship\CSV\data\204-csv\963.csv
# Processing file: F:\Internship\CSV\data\204-csv\964.csv
# Processing file: F:\Internship\CSV\data\204-csv\965.csv
# Processing file: F:\Internship\CSV\data\204-csv\966.csv
# Error parsing F:\Internship\CSV\data\204-csv\966.csv: Error tokenizing data. C error: Expected 5 fields in line 11, saw 6
#
# Processing file: F:\Internship\CSV\data\204-csv\967.csv
# Processing file: F:\Internship\CSV\data\204-csv\968.csv
# Processing file: F:\Internship\CSV\data\204-csv\969.csv
# Processing file: F:\Internship\CSV\data\204-csv\97.csv
# Processing file: F:\Internship\CSV\data\204-csv\970.csv
# Processing file: F:\Internship\CSV\data\204-csv\971.csv
# Processing file: F:\Internship\CSV\data\204-csv\972.csv
# Processing file: F:\Internship\CSV\data\204-csv\973.csv
# Processing file: F:\Internship\CSV\data\204-csv\974.csv
# Processing file: F:\Internship\CSV\data\204-csv\975.csv
# Processing file: F:\Internship\CSV\data\204-csv\976.csv
# Processing file: F:\Internship\CSV\data\204-csv\977.csv
# Processing file: F:\Internship\CSV\data\204-csv\978.csv
# Processing file: F:\Internship\CSV\data\204-csv\979.csv
# Processing file: F:\Internship\CSV\data\204-csv\98.csv
# Processing file: F:\Internship\CSV\data\204-csv\980.csv
# Processing file: F:\Internship\CSV\data\204-csv\981.csv
# Error parsing F:\Internship\CSV\data\204-csv\981.csv: Error tokenizing data. C error: Expected 5 fields in line 6, saw 7
#
# Processing file: F:\Internship\CSV\data\204-csv\982.csv
# Processing file: F:\Internship\CSV\data\204-csv\983.csv
# Processing file: F:\Internship\CSV\data\204-csv\984.csv
# Processing file: F:\Internship\CSV\data\204-csv\985.csv
# Processing file: F:\Internship\CSV\data\204-csv\986.csv
# Processing file: F:\Internship\CSV\data\204-csv\987.csv
# Processing file: F:\Internship\CSV\data\204-csv\988.csv
# Processing file: F:\Internship\CSV\data\204-csv\989.csv
# Processing file: F:\Internship\CSV\data\204-csv\99.csv
# Processing file: F:\Internship\CSV\data\204-csv\990.csv
# Processing file: F:\Internship\CSV\data\204-csv\991.csv
# Processing file: F:\Internship\CSV\data\204-csv\992.csv
# Processing file: F:\Internship\CSV\data\204-csv\993.csv
# Processing file: F:\Internship\CSV\data\204-csv\994.csv
# Processing file: F:\Internship\CSV\data\204-csv\995.csv
# Processing file: F:\Internship\CSV\data\204-csv\996.csv
# Processing file: F:\Internship\CSV\data\204-csv\997.csv
# Processing file: F:\Internship\CSV\data\204-csv\998.csv
# Processing file: F:\Internship\CSV\data\204-csv\999.csv
# Successfully processed all CSV files!

# %%
from llama_index.core.program import LLMTextCompletionProgram
from llama_index.core.bridge.pydantic import BaseModel, Field
from llama_index.llms.huggingface import HuggingFaceLLM
import torch
from transformers import BitsAndBytesConfig



class TableInfo(BaseModel):
	"""Information regarding a structured table."""

	table_name: str = Field(
		..., description="table name (must be underscores and NO spaces)"
	)
	table_summary: str = Field(
		..., description="short, concise summary/caption of the table"
	)


prompt_str = """\
Give me a summary of the table with the following JSON format.

- The table name must be unique to the table and describe it while being concise.
- Do NOT output a generic table name (e.g. table, my_table).

Do NOT make the table name one of the following: {exclude_table_name_list}

Table:
{table_str}

Summary: """

quantization_config = BitsAndBytesConfig(
  load_in_4bit=True,
  bnb_4bit_compute_dtype=torch.float16,
  bnb_4bit_quant_type="nf4",
  bnb_4bit_use_double_quant=True,
)



# quantization_config = BitsAndBytesConfig(
#   load_in_8bit=True,  # Load the model in 8-bit format
#   bnb_8bit_compute_dtype=torch.float16,  # Use float16 for internal computations
#   bnb_8bit_quant_type="tensor_qint8",  # Quantize weights and activations to 8-bit integer
# )


llm = HuggingFaceLLM(
generate_kwargs={"temperature": 0.50, "do_sample": True},
tokenizer_name="mistralai/Mistral-7B-Instruct-v0.2",
model_name="mistralai/Mistral-7B-Instruct-v0.2",
device_map="cuda",
model_kwargs={"torch_dtype": torch.float16 , "quantization_config": quantization_config }
)


program = LLMTextCompletionProgram.from_defaults(
	output_cls=TableInfo,
	llm=llm,
	prompt_template_str=prompt_str,
)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# import os
# os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
import os

# Define the desired directory path
tableinfo_dir = "WikiTableQuestions_TableInfo"

# Check if the directory already exists
if not os.path.exists(tableinfo_dir):
    # Create the directory using os.mkdir()
    os.mkdir(tableinfo_dir)
else:
    # If the directory already exists, move on
    print(f"Directory '{tableinfo_dir}' already exists. Continuing execution.")
# Out:
# Directory 'WikiTableQuestions_TableInfo' already exists. Continuing execution.

# %%
import json


def _get_tableinfo_with_index(idx: int) -> str:
	# ... (rest of the function remains the same)
	results_gen = Path(tableinfo_dir).glob(f"{idx}_*")
	results_list = list(results_gen)
	if len(results_list) == 0:
		return None
	elif len(results_list) == 1:
		path = results_list[0]
		return TableInfo.parse_file(path)
	else:
		raise ValueError(
			f"More than one file matching index: {list(results_gen)}"
		)
table_names = set()
table_infos = []
for idx, df in enumerate(dfs):
	table_info = _get_tableinfo_with_index(idx)
	if table_info:
		table_infos.append(table_info)
	else:
		# Try to generate table info with program (once)
		num_tries = 1
		while num_tries <= 1:  # Limit to one retry
			df_str = df.head(10).to_csv()
			try:
				table_info = program(
					table_str=df_str,
					exclude_table_name_list=str(list(table_names)),
				)
				table_name = table_info.table_name
				print(f"Processed table: {table_name} (Try {num_tries})")
				if table_name not in table_names:
					table_names.add(table_name)
					break  # Success, exit the loop
				else:
					print(f"Table name {table_name} already exists. Moving to next file.")
					num_tries += 1  # Increment retry count
			except ValidationError:
				print(f"Error generating table info for index {idx}: Validation error. Ignoring and continuing.")
				pass  # Ignore ValidationError and continue

		# If loop finishes without a break (no success), move to next file
		if num_tries > 1:
			print(f"Failed to generate unique table name for index {idx}. Skipping.")

	# Save table info only if successful (original logic remains)
	if table_info:
		out_file = f"{tableinfo_dir}/{idx}_{table_name}.json"
		json.dump(table_info.dict(), open(out_file, "w"))
		table_infos.append(table_info)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# c:\Users\kv23k\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\mistral\modeling_mistral.py:688: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Album_Chart_Positions (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: MediaCredits (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Yearly_Deaths_and_Accidents (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Academy_Awards_1972 (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Award_Nominations (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: BadBoyArtistsAlbums (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: YanktonBroadcastingTable (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: MissingPersonsAugust1982 (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Chart_Positions_And_Certifications (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: KodachromeFilmHistory (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: BBC_Radio_Annual_Costs (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: AirportUsageTable (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Voter_Registration_Statistics (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Norwegian_Football_Performance (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: HorseRacingChampions (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Grammy_Awards (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: BoxingResults (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: early_20th_century_football_coaches (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: JapanesePrefectureDemographics (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: VoterRegistrationStatistics (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: FrenchActressAwards (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: UK_Ministers_and_their_Offices (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: MunicipalityMergers (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Football_League_Table_20XX (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: BinaryEncodedProbabilitiesTable (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Monthly_Average_Temperatures_and_Precipitation (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: ItalianPoliticalLeaders (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: NewMexicoPoliticalOfficers (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: WeatherMonthlyAverages (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: ManhattanProjectMilestones (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Average_Monthly_Temperatures_and_Precipitation (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: AfrikaansGreetings (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: School_Districts_and_Enrollment_Processes (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Growth_Factors_And_Tyrosine_Kinases_Associated_With_Cancer (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Peak_Chart_Positions_and_Certifications (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: French_Politicians_and_Their_Careers (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Norwegian_Politicians_And_Their_Occupations_1900s (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Danish_and_Swedish_Population_Density_by_Region (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: US_Census_City_Population_Change (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: DelawareBridges (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: ChartPositionsForSongsByYear (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Williams_Air_Force_Base_Landmarks (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: MusicFestivalLineups (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: TopMovieRevenues (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: FamousFerrisWheels (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: ParliamentaryRepresentation (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: BritishFilmReleasesWithRoles (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Monthly_Weather_Averages (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: FilmAndRoleTable1986_1993 (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Last_of_the_Three_Scarfers_Episodes (Try 1)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Processed table: Scottish_Leaders_Party_And_Tenure (Try 1)
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\kv23k\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydantic\v1\main.py:539, in BaseModel.parse_raw(cls, b, content_type, encoding, proto, allow_pickle)
#     538 try:
# --> 539     obj = load_str_bytes(
#     540         b,
#     541         proto=proto,
#     542         content_type=content_type,
#     543         encoding=encoding,
#     544         allow_pickle=allow_pickle,
#     545         json_loads=cls.__config__.json_loads,
#     546     )
#     547 except (ValueError, TypeError, UnicodeDecodeError) as e:
#
# File c:\Users\kv23k\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydantic\v1\parse.py:37, in load_str_bytes(b, content_type, encoding, proto, allow_pickle, json_loads)
#      36         b = b.decode(encoding)
# ---> 37     return json_loads(b)
#      38 elif proto == Protocol.pickle:
#
# File c:\Users\kv23k\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\kv23k\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 5 column 1 (char 136)
#
# During handling of the above exception, another exception occurred:
#
# ValidationError                           Traceback (most recent call last)
# Cell In[8], line 29
#      28 try:
# ---> 29 	table_info = program(
#      30 		table_str=df_str,
#      31 		exclude_table_name_list=str(list(table_names)),
#      32 	)
#      33 	table_name = table_info.table_name
#
# File c:\Users\kv23k\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\program\llm_program.py:103, in LLMTextCompletionProgram.__call__(self, llm_kwargs, *args, **kwargs)
#     101     raw_output = response.text
# --> 103 output = self._output_parser.parse(raw_output)
#     104 if not isinstance(output, self._output_cls):
#
# File c:\Users\kv23k\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\output_parsers\pydantic.py:62, in PydanticOutputParser.parse(self, text)
#      61 json_str = extract_json_str(text)
# ---> 62 return self._output_cls.parse_raw(json_str)
#
# File c:\Users\kv23k\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydantic\v1\main.py:548, in BaseModel.parse_raw(cls, b, content_type, encoding, proto, allow_pickle)
#     547 except (ValueError, TypeError, UnicodeDecodeError) as e:
# --> 548     raise ValidationError([ErrorWrapper(e, loc=ROOT_KEY)], cls)
#     549 return cls.parse_obj(obj)
#
# ValidationError: 1 validation error for TableInfo
# __root__
#   Extra data: line 5 column 1 (char 136) (type=value_error.jsondecode; msg=Extra data; doc={
#   "table_name": "RugbyUnionPointsTable",
#   "table_summary": "Summary of the points earned by various rugby union clubs in a season"
# }
# ```
#
#
# ```json
# {
#   "table_name": "RugbyUnionClubPoints",
#   "table_summary": "Table of points earned by different rugby union clubs in a season"
# }
# ```
#
#
# ```json
# {
#   "table_name": "RugbyUnionClubStats",
#   "table_summary": "A summary of statistics for rugby union clubs, including points earned"
# }
# ```
#
#
# ```json
# {
#   "table_name": "RugbyUnionClubPerformance",
#   "table_summary": "A table of performance statistics for rugby union clubs, including points earned"
# }
# ```
#
#
# ```json
# {
#   "table_name": "RugbyUnionPointsSummary",
#   "table_summary": "Summary of points earned by various rugby union clubs in a season"
# }; pos=136; lineno=5; colno=1)
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 41
#      39 		print(f"Table name {table_name} already exists. Moving to next file.")
#      40 		num_tries += 1  # Increment retry count
# ---> 41 except ValidationError:
#      42 	print(f"Error generating table info for index {idx}: Validation error. Ignoring and continuing.")
#      43 	pass  # Ignore ValidationError and continue
#
# NameError: name 'ValidationError' is not defined

# %%
from sqlalchemy import (
	create_engine,
	MetaData,
	Table,
	Column,
	String,
	Integer,
	exc,  # Import the `exc` submodule for exception handling
)
import pandas as pd


import re


# Function to create a sanitized column name
def sanitize_column_name(col_name):
	# ... (rest of the function remains the same)
	return re.sub(r"\W+", "_", col_name)

# Function to create a table from a DataFrame using SQLAlchemy
def create_table_from_dataframe(
	df: pd.DataFrame, table_name: str, engine, metadata_obj
):
	# Sanitize column names
	sanitized_columns = {col: sanitize_column_name(col) for col in df.columns}
	df = df.rename(columns=sanitized_columns)

	# Dynamically create columns based on DataFrame columns and data types
	columns = [
		Column(col, String if dtype == "object" else Integer)
		for col, dtype in zip(df.columns, df.dtypes)
	]

	# Create a table with the defined columns
	table = Table(table_name, metadata_obj,extend_existing=True, *columns)

	# Create the table in the database
	metadata_obj.create_all(engine)

	# Insert data with exception handling (skip rows with missing columns)
	with engine.connect() as conn:
		for _, row in df.iterrows():
			try:
				insert_stmt = table.insert().values(**row.to_dict())
				conn.execute(insert_stmt)
			except exc.OperationalError as e:
				# Likely due to missing column in the table
				print(f"Error inserting row for {table_name}: {e}")
				continue  # Skip to the next row

		conn.commit()


engine = create_engine("sqlite:///local_db.db")
metadata_obj = MetaData()
for idx, df in enumerate(dfs):
	tableinfo = _get_tableinfo_with_index(idx)
	print(f"Creating table: {tableinfo.table_name}")
	create_table_from_dataframe(df, tableinfo.table_name, engine, metadata_obj)
# Out:
# Creating table: Album_Chart_Positions
# Creating table: MediaCredits
# Creating table: Yearly_Deaths_and_Accidents
# Creating table: Academy_Awards_1972
# Creating table: Award_Nominations
# Creating table: BadBoyArtistsAlbums
# Creating table: YanktonBroadcastingTable
# Creating table: MissingPersonsAugust1982
# Creating table: Chart_Positions_And_Certifications
# Creating table: KodachromeFilmHistory
# Creating table: BBC_Radio_Annual_Costs
# Creating table: AirportUsageTable
# Creating table: Voter_Registration_Statistics
# Creating table: Norwegian_Football_Performance
# Creating table: HorseRacingChampions
# Creating table: Grammy_Awards
# Creating table: BoxingResults
# Creating table: early_20th_century_football_coaches
# Creating table: JapanesePrefectureDemographics
# Creating table: VoterRegistrationStatistics
# Creating table: FrenchActressAwards
# Creating table: UK_Ministers_and_their_Offices
# Creating table: MunicipalityMergers
# Creating table: Football_League_Table_20XX
# Creating table: BinaryEncodedProbabilitiesTable
# Creating table: Monthly_Average_Temperatures_and_Precipitation
# Creating table: ItalianPoliticalLeaders
# Creating table: NewMexicoPoliticalOfficers
# Creating table: WeatherMonthlyAverages
# Creating table: ManhattanProjectMilestones
# Creating table: Average_Monthly_Temperatures_and_Precipitation
# Creating table: AfrikaansGreetings
# Creating table: School_Districts_and_Enrollment_Processes
# Creating table: Growth_Factors_And_Tyrosine_Kinases_Associated_With_Cancer
# Creating table: Peak_Chart_Positions_and_Certifications
# Creating table: French_Politicians_and_Their_Careers
# Creating table: Norwegian_Politicians_And_Their_Occupations_1900s
# Creating table: Danish_and_Swedish_Population_Density_by_Region
# Creating table: US_Census_City_Population_Change
# Creating table: DelawareBridges
# Creating table: ChartPositionsForSongsByYear
# Creating table: Williams_Air_Force_Base_Landmarks
# Creating table: MusicFestivalLineups
# Creating table: TopMovieRevenues
# Creating table: FamousFerrisWheels
# Creating table: ParliamentaryRepresentation
# Creating table: BritishFilmReleasesWithRoles
# Creating table: Monthly_Weather_Averages
# Creating table: FilmAndRoleTable1986_1993
# Creating table: Last_of_the_Three_Scarfers_Episodes
# Creating table: Scottish_Leaders_Party_And_Tenure
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 59
#      57 for idx, df in enumerate(dfs):
#      58 	tableinfo = _get_tableinfo_with_index(idx)
# ---> 59 	print(f"Creating table: {tableinfo.table_name}")
#      60 	create_table_from_dataframe(df, tableinfo.table_name, engine, metadata_obj)
#
# AttributeError: 'NoneType' object has no attribute 'table_name'

# %%
# pip install llama-index-embeddings-huggingface

from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings

Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding  # Use pre-built Hugging Face embedding

# Alternatively, uncomment these lines if you prefer a custom TextEmbeddingModel:
from llama_index.core import VectorStoreIndex
# from llama_index.core import TextEmbeddingModel / # Might require specific version of llama_index
from llama_index.core.objects import (  # Might require specific version of llama_index
	SQLTableNodeMapping,
	ObjectIndex,
	SQLTableSchema,
)

# Downloaded Hugging Face model (replace with your actual model name)
model_name = "BAAI/bge-small-en-v1.5"  # Adjust with the name of your downloaded model

# Option 1: Use pre-built Hugging Face embedding (recommended)
embedding_model = HuggingFaceEmbedding(model_name=model_name)

# Option 2: Use custom TextEmbeddingModel (uncomment the imports above)
# class CustomEmbeddingModel(TextEmbeddingModel):
#     # ... (Implement your custom text embedding logic here)
# embedding_model = CustomEmbeddingModel(...)  # Initialize your custom model

from llama_index.core import SQLDatabase, VectorStoreIndex  # Import from llama_index

sql_database = SQLDatabase(engine)

table_node_mapping = SQLTableNodeMapping(sql_database)
table_schema_objs = [
	SQLTableSchema(table_name=t.table_name, context_str=t.table_summary)
	for t in table_infos
]  # Add a SQLTableSchema for each table


def get_text_embedding(text):
	# This function might not be needed if using HuggingFaceEmbedding
	# You can remove it if not used.
	pass  # Placeholder, not required with HuggingFaceEmbedding


# Use the chosen embedding model
obj_index = ObjectIndex.from_objects(
	table_schema_objs,
	table_node_mapping,
	VectorStoreIndex,
	# Use VectorStoreIndex for retrieval (might need adjustment)
	embedding_model=embedding_model,
)
obj_retriever = obj_index.as_retriever(similarity_top_k=3)

# %%
from llama_index.core.retrievers import SQLRetriever
from typing import List
from llama_index.core.query_pipeline import FnComponent

sql_retriever = SQLRetriever(sql_database)


def get_table_context_str(table_schema_objs: List[SQLTableSchema]):
	"""Get table context string."""
	context_strs = []
	for table_schema_obj in table_schema_objs:
		table_info = sql_database.get_single_table_info(
			table_schema_obj.table_name
		)
		if table_schema_obj.context_str:
			table_opt_context = " The table description is: "
			table_opt_context += table_schema_obj.context_str
			table_info += table_opt_context

		context_strs.append(table_info)
	return "\n\n".join(context_strs)


table_parser_component = FnComponent(fn=get_table_context_str)

# %%
from llama_index.core.prompts.default_prompts import DEFAULT_TEXT_TO_SQL_PROMPT
from llama_index.core import PromptTemplate
from llama_index.core.query_pipeline import FnComponent
from llama_index.core.llms import CompletionResponse


def parse_response_to_sql(response: CompletionResponse) -> str:
	"""Parse response to SQL."""
	# Access text content directly from CompletionResponse
	response_text = response.text
	sql_query_start = response_text.find("SQLQuery:")
	if sql_query_start != -1:
		response_text = response_text[sql_query_start:]
		# No need for additional check as 'SQLQuery:' should be at the beginning
		response_text = response_text[len("SQLQuery:"):]
	sql_result_start = response_text.find("SQLResult:")
	if sql_result_start != -1:
		response_text = response_text[:sql_result_start]
	return response_text.strip().strip("```").strip()



sql_parser_component = FnComponent(fn=parse_response_to_sql)

text2sql_prompt = DEFAULT_TEXT_TO_SQL_PROMPT.partial_format(
		dialect=engine.dialect.name
)
print(text2sql_prompt.template)
# Out:
# Given an input question, first create a syntactically correct {dialect} query to run, then look at the results of the query and return the answer. You can order the results by a relevant column to return the most interesting examples in the database.
#
# Never query for all the columns from a specific table, only ask for a few relevant columns given the question.
#
# Pay attention to use only the column names that you can see in the schema description. Be careful to not query for columns that do not exist. Pay attention to which column is in which table. Also, qualify column names with the table name when needed. You are required to use the following format, each taking one line:
#
# Question: Question here
# SQLQuery: SQL Query to run
# SQLResult: Result of the SQLQuery
# Answer: Final answer here
#
# Only use tables listed below.
# {schema}
#
# Question: {query_str}
# SQLQuery:

# %%
response_synthesis_prompt_str = (
	"Given an input question, synthesize a response from the query results and the Answer which is generated from the SQLResults\n"
	"Query: {query_str}\n"
	"SQL: {sql_query}\n"
	"SQL Response: {context_str}\n"
	"Response: "
)
response_synthesis_prompt = PromptTemplate(
	response_synthesis_prompt_str,
)

# %%
from llama_index.core.query_pipeline import (
	QueryPipeline as QP,
	Link,
	InputComponent,
	CustomQueryComponent,
)

qp = QP(
	modules={
		"input": InputComponent(),
		"table_retriever": obj_retriever,
		"table_output_parser": table_parser_component,
		"text2sql_prompt": text2sql_prompt,
		"text2sql_llm": llm,
		"sql_output_parser": sql_parser_component,
		"sql_retriever": sql_retriever,
		"response_synthesis_prompt": response_synthesis_prompt,
		"response_synthesis_llm": llm,
	},
	verbose=True,
)

# %%
qp.add_chain(["input", "table_retriever", "table_output_parser"])
qp.add_link("input", "text2sql_prompt", dest_key="query_str")
qp.add_link("table_output_parser", "text2sql_prompt", dest_key="schema")
qp.add_chain(
	["text2sql_prompt", "text2sql_llm", "sql_output_parser", "sql_retriever"]
)
qp.add_link(
	"sql_output_parser", "response_synthesis_prompt", dest_key="sql_query"
)
qp.add_link(
	"sql_retriever", "response_synthesis_prompt", dest_key="context_str"
)
qp.add_link("input", "response_synthesis_prompt", dest_key="query_str")
qp.add_link("response_synthesis_prompt", "response_synthesis_llm")

# %%
response = qp.run(
	query="What is the population of danish capital region"
)
print(response.text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# > Running module input with input:
# query: What is the population of danish capital region
#
# > Running module table_retriever with input:
# input: What is the population of danish capital region
#
# > Running module table_output_parser with input:
# table_schema_objs: [SQLTableSchema(table_name='Danish_and_Swedish_Population_Density_by_Region', context_str='A table showing the population, area, and density (population per square kilometer) for different regions wit...
#
# > Running module text2sql_prompt with input:
# query_str: What is the population of danish capital region
# schema: Table 'Danish_and_Swedish_Population_Density_by_Region' has columns: Region (VARCHAR), Population (VARCHAR), Area (VARCHAR), Density (VARCHAR), and foreign keys: . The table description is: A table sh...
#
# > Running module text2sql_llm with input:
# prompt: Given an input question, first create a syntactically correct sqlite query to run, then look at the results of the query and return the answer. You can order the results by a relevant column to return...
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# > Running module sql_output_parser with input:
# response:
# SELECT Population FROM Danish_and_Swedish_Population_Density_by_Region WHERE Region = 'Danish Capital Region';
# SQLResult: '1,320,898'
# Answer: The population of the Danish Capital Region is 1,320,898.
#
# > Running module sql_retriever with input:
# input: SELECT Population FROM Danish_and_Swedish_Population_Density_by_Region WHERE Region = 'Danish Capital Region';
#
# > Running module response_synthesis_prompt with input:
# query_str: What is the population of danish capital region
# sql_query: SELECT Population FROM Danish_and_Swedish_Population_Density_by_Region WHERE Region = 'Danish Capital Region';
# context_str: [NodeWithScore(node=TextNode(id_='3829a5c0-ad76-418b-b252-3513fcdab8d2', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="[('1,823,1...
#
# > Running module response_synthesis_llm with input:
# prompt: Given an input question, synthesize a response from the query results and the Answer which is generated from the SQLResults
# Query: What is the population of danish capital region
# SQL: SELECT Populatio...
#
# 1,823,109
#
# Note: The SQLResults format is a JSON-like string. The response is generated by extracting and parsing the population value from the response string.
